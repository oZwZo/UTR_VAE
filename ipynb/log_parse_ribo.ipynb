# %%
import os
import sys
import PATH
import re
from importlib import reload

import numpy as np
import pandas as pd

from models import MTL_models
from models import log_and_save as LAS
from matplotlib import pyplot as plt

reload(LAS)

def read_log_of_a_dir(log_dir,**kwarg):
    """
    ...log_dir : abs path of log dir
    """
    file_ls = [file for file in os.listdir(log_dir) if ".log" in file]
    log_path = [os.path.join(log_dir,file) for file in file_ls]
    log_name = [file.replace('.log','') for file in file_ls]
    log_ls = [LAS.Log_parser(file,**kwarg) for file in log_path]
    return log_ls,log_name
# Out:
# /home/wergillius/Project/UTR_VAE

# %%
plt.style.use('dark_background')
one_dark_pro = (41/255,44/255,51/255)
plt.rcParams['axes.facecolor'] = one_dark_pro
plt.rcParams['figure.facecolor'] = one_dark_pro

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('default')

# %%
LAS.plot_a_exp_set(bcb_log_ls,bcb_log_name,marker='.',alpha=0.7,dataset='train',mean_of_train=6,fig=plt.figure(figsize=(30,4)),check_time=1)

# %%
reload(LAS)
# Out:
# <module 'models.log_and_save' from '/home/wergillius/Project/UTR_VAE/models/log_and_save.py'>

# %% [markdown]
# # ribo

# %% [markdown]
# ## model : `RL_regressor`

# %%
ribo_tr_dir="/home/wergillius/Project/UTR_VAE/log/Backbone/RL_regressor_ribo/test_run"
tr_log_ls, tr_log_name = read_log_of_a_dir(ribo_tr_dir)

# %%
tr_log_ls = tr_log_ls[:5]
tr_log_name = tr_log_name[:5]

# %%
LAS.plot_a_exp_set(tr_log_ls,tr_log_name,alpha=0.8,marker='o')
LAS.plot_a_exp_set(tr_log_ls,tr_log_name,dataset="train",mean_of_train=6,alpha=0.7)

# %% [markdown]
# ## Transfer

# %%
ribo_tnsfr_dir="/home/wergillius/Project/UTR_VAE/log/Backbone/RL_regressor_ribo/transfer"
tnsfr_log_ls, tnsfr_log_name = read_log_of_a_dir(ribo_tnsfr_dir)

# %%
LAS.plot_a_exp_set(tnsfr_log_ls, tnsfr_log_name,alpha=0.8,marker='o')
LAS.plot_a_exp_set(tnsfr_log_ls, tnsfr_log_name,dataset="train",mean_of_train=6,alpha=0.7)

# %%
v

# %% [markdown]
# ## RL_regressor test_trainval

# %%
bcb_log_dir="/home/wergillius/Project/UTR_VAE/log/Backbone/RL_regressor_ribo/test_trainval_bcb"
bcb_log_ls,bcb_log_name = read_log_of_a_dir(bcb_log_dir)

# %%
LAS.plot_a_exp_set(bcb_log_ls,bcb_log_name,marker='o',alpha=0.7,fig=plt.figure(figsize=(30,4)),check_time=2)
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
LAS.plot_a_exp_set(bcb_log_ls,bcb_log_name,marker='.',alpha=0.7,dataset='train',mean_of_train=6,fig=plt.figure(figsize=(30,4)),check_time=1)

# %% [markdown]
# ## RL_regressor `old_train_val`

# %%
oldtv_trans = "/home/wergillius/Project/UTR_VAE/log/Backbone/RL_regressor_ribo/transfer_with_old_backbone_trainval"
oldtv_log_ls,oldtv_log_name = LAS.read_log_of_a_dir(oldtv_trans)

# %%
oldtv_log_name[:5]
# Out:
# ['2nd_finetune_last3_fromdebug',
#  'finetune_last3',
#  'unfix_all_l1',
#  'debug_transfer',
#  '2nd_finetune_last3']

# %%
oldtv_fig=plt.figure(figsize=(40,6))
LAS.plot_a_exp_set(oldtv_log_ls[:5],oldtv_log_name[:5],marker='o',alpha=0.7,fig=oldtv_fig,check_time=1,start_from=20);
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
oldtv_fig.axes[1]
# Out:
# <AxesSubplot:title={'center':'Val LOSS'}>

# %%
LAS.plot_a_exp_set(oldtv_log_ls,oldtv_log_name,marker='.',alpha=0.7,dataset='train',mean_of_train=6,fig=plt.figure(figsize=(40,6)),check_time=1,start_from=10)

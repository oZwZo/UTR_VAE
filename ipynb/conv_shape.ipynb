# %% [markdown]
# # test DL models

# %% [markdown]
# ## so much import

# %%
import os
import sys
import pandas as pd
import numpy as np
import re
import PATH
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader,Dataset,random_split
from tqdm import tqdm

from matplotlib import pyplot as plt
import scipy.stats as stats
import seaborn as sns

from models.popen import Auto_popen
from models import ScheduleOptimizer
from models.ScheduleOptimizer import ScheduledOptim 
from models.log_and_save import Log_parser,plot_a_exp_set
from models import reader
from models import DL_models
from models import CNN_models

from utils import Seq_one_hot,read_UTR_csv,read_label,resume
# Out:
# /home/wergillius/Project/UTR_VAE

# %%
from importlib import reload
from models import popen

# %%
import logging

# %%
# define data
dataset = reader.UTR_dataset(cell_line='A549')

# train_loader,val_loader,test_loader = reader.get_splited_dataloader(dataset,
#                                                                     ratio=[0.7,0.2,0.1],
#                                                                     batch_size=10,
#                                                                     num_workers=4)
# train_loader,val_loader,test_loader = reader.get_mask_dataloader(20,4)
train_loader,val_loader,test_loader = reader.get_mix_dataloader(200,4)
val_iter=iter(val_loader)

# %% [markdown]
# ## the kernel shape

# %%
def cal_convTrans_shape(L_in,kernel_size,padding=0,stride=1,diliation=1,out_padding=0):
    """
    For convolution Transpose 1D decoding , compute the final length
    """
    L_out = (L_in -1 )*stride + diliation*(kernel_size -1 )+1-2*padding + out_padding 
    return L_out

def cal_conv_shape(L_in,kernel_size,padding=0,diliation=1,stride=1):
    """
    For convolution 1D encoding , compute the final length 
    """
    L_out = 1+ (L_in + 2*padding -diliation*(kernel_size-1) -1)/stride
    return L_out

# %%
Chann = [4,16,32,64,128]
pad_ls = [1,1,1,1]
dialiation_ls = [1,1,1,1,1]
stride = [1,2,2,2]
L_in = 17
for i in range(len(Chann)-1):
    L_out = cal_conv_shape(L_in,3,padding=pad_ls[i],diliation=dialiation_ls[i],stride=stride[i])
    L_in = L_out
    print(L_out)
# Out:
# 17.0
# 9.0
# 5.0
# 3.0

# %%
L_in = 8*(L_out -1 ) +1

# %%
L_in
# Out:
# 57.0

# %%
Chann = [4,16,32,64]
pad_ls = [0,0,0,0]
dialiation_ls = [1,1,1,1,1]
L_in = 100
for i in range(len(Chann)-1):
    L_out = cal_conv_shape(L_in,4,stride=1,padding=pad_ls[i],diliation=dialiation_ls[i])
    L_in = L_out
    print(L_out)
# Out:
# 97.0
# 94.0
# 91.0

# %%
Chann = [4,16,32,64,128]
pad_ls = [1,0] #[1,0,1,0]
dialiation_ls = [1,1] # [1,1,1,1]
L_in = 24
for i in range(len(Chann)-1):
    L_out = cal_convTrans_shape(L_in,4,stride=2,padding=pad_ls[::-1][i],out_padding=0,diliation=dialiation_ls[::-1][i])
    L_in = L_out
    print(L_out)
# Out:
# 50
# 100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-6bd21c0df8f9> in <module>
#       4 L_in = 24
#       5 for i in range(len(Chann)-1):
# ----> 6     L_out = cal_convTrans_shape(L_in,4,stride=2,padding=pad_ls[::-1][i],out_padding=0,diliation=dialiation_ls[::-1][i])
#       7     L_in = L_out
#       8     print(L_out)
#
# IndexError: list index out of range

# %%
Chann = [4,16,32,64,128]
pad_ls = [1,0,1,0]
Conv_sequence = nn.ModuleList(
    [nn.Conv1d(Chann[i],Chann[i+1],4,stride=2,padding=pad_ls[i]) for i in range(len(Chann)-1)]
)
Deconv_sequqnce = nn.ModuleList(
    [nn.ConvTranspose1d(Chann[::-1][i],Chann[::-1][i+1],4,stride=2,padding=pad_ls[::-1][i]) for i in range(len(Chann)-1)]
)

# %%
out = X_conv
print("start Conv")
for model in Conv_sequence:
    out = model(out)
    print(out.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d944a6a11e9b> in <module>
# ----> 1 out = X_conv
#       2 print("start Conv")
#       3 for model in Conv_sequence:
#       4     out = model(out)
#       5     print(out.shape)
#
# NameError: name 'X_conv' is not defined

# %%
print("start Deconv")
for model in Deconv_sequqnce:
    out = model(out)
    print(out.shape)
# Out:
# start Deconv
# torch.Size([10, 64, 12])
# torch.Size([10, 32, 24])
# torch.Size([10, 16, 50])
# torch.Size([10, 4, 100])

# %%
from importlib import reload

# %%
from models import CNN_models
reload(CNN_models)
# Out:
# <module 'models.CNN_models' from '/home/wergillius/Project/UTR_VAE/models/CNN_models.py'>

# %%
model = CNN_models.Conv_AE(channel_ls=[4,16,32,64,128], padding_ls=[1,0,1,0])

# %%
X = X.transpose(1,2)

# %%
X.shape
# Out:
# torch.Size([10, 4, 100])

# %%
out = model(X)

# %%
out.shape
# Out:
# torch.Size([10, 4, 100])

# %% [markdown]
# ## compute acc function

# %%
def compute_acc(X,out):
    batch_size = X.shape       # B*100*4
    true_max=torch.argmax(X,dim=2)

    recon_max=torch.argmax(out,dim=2)

    return torch.sum(true_max == recon_max).item()

# %%
def reconstruct_seq(out_seq,X):
    seq = torch.zeros_like(X)
#     out_seq = torch.cat(out_seq,dim=1)
    position = torch.argmax(out_seq,dim=2)     # X_reconst : b*100*4

    for batch_idx in range(X.shape):
        for i,j in enumerate(position[batch_idx]):
            seq[batch_idx,i,j.item()] = 1     
            
    return torch.mean(X.mul(seq).sum(dim=2).sum(dim=1))

# %%
out_T = out.transpose(1,2)
X_T = X.transpose(1,2)

out_T.shape
# Out:
# torch.Size([10, 100, 4])

# %%
# %timeit compute_acc(X,out)
# Out:
# 519 µs ± 60.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit reconstruct_seq(out_T,X_T)
# Out:
# 13.2 ms ± 1.55 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## plot result

# %% [markdown]
# $$    \ell(x, y) = L = \{l_1,\dots,l_N\}^\top, \quad
#     l_n = \left( x_n - y_n \right)^2,$$
#
# where $N$ is the batch size. If :attr:`reduction` is not ``'none'``
# (default ``'mean'``), then:
#
# $$    \ell(x, y) =
#     \begin{cases}
#         \operatorname{mean}(L), &  \text{if reduction} = \text{'mean';}\\
#         \operatorname{sum}(L),  &  \text{if reduction} = \text{'sum'.}
#     \end{cases}$$
#
# :$x$ and :$y$ are tensors of arbitrary shapes with a total
# of :$n$ elements each

# %%
# Conv_popen = popen.Auto_popen("/home/wergillius/Project/UTR_VAE/log/Conv_AE_mask/setting1/mask_setting1.ini")

Conv_popen = popen.Auto_popen("/home/wergillius/Project/UTR_VAE/log/Conv_AE_mix/setting1/mix_test.ini")
logger = logging.getLogger("VAE")
Conv_popen.check_experiment(logger)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-363deca5ea7f> in <module>
#       1 # Conv_popen = popen.Auto_popen("/home/wergillius/Project/UTR_VAE/log/Conv_AE_mask/setting1/mask_setting1.ini")
#       2
# ----> 3 Conv_popen = popen.Auto_popen("/home/wergillius/Project/UTR_VAE/log/Conv_AE_mix/setting1/mix_test.ini")
#       4 logger = logging.getLogger("VAE")
#       5 Conv_popen.check_experiment(logger)
#
# ~/Project/UTR_VAE/models/popen.py in __init__(self, config_file)
#      36
#      37         # generate self.model_args
# ---> 38         self.get_model_config()
#      39
#      40     def set_attr_from_dict(self,attr_ls):
#
# ~/Project/UTR_VAE/models/popen.py in get_model_config(self)
#      86                              self.config_dict["diliat_ls"],
#      87                              self.config_dict["latent_dim"],
# ---> 88                              self.config_dict["kernel_size"]]
#      89
#      90     def check_experiment(self,logger):
#
# KeyError: 'kernel_size'

# %%
Conv_popen.Resumable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-570c902be220> in <module>
# ----> 1 Conv_popen.Resumable
#
# NameError: name 'Conv_popen' is not defined

# %%
# read model
model = CNN_models.Conv_AE(*Conv_popen.model_args)
optimizer = eval(ScheduleOptimizer.scheduleoptim_text)
resume(Conv_popen,model,optimizer,logger)
# Out:
# (571, 4.05402245069854, 60.48962563451777)

# %%
# from train loader get some data
batch_data = next(val_iter)

X, y = batch_data
X = X.float()
y = y

# %%
out=model(X,epoch=None,Y=y)

re_X = model.reconstruct_seq(out,y)

# %%
n_iter = (i for i in range(200))

# %%
def visiualize_result(out,re_X,X,y):
    fig=  plt.figure(figsize=(15,10))
    
    ax = fig.add_subplot(4,1,1)
    ax.imshow(out.detach().numpy().T,aspect='auto')
    ax.set_title("OUT")
    ax.axis("off")

    ax2 = fig.add_subplot(4,1,2)
    ax2.imshow(re_X.detach().numpy().T,aspect='auto')
    ax2.set_title("reconstruced")
    ax2.axis('off')

    ax3 = fig.add_subplot(4,1,3)
    ax3.imshow(X.detach().numpy().T,aspect='auto')
    ax3.set_title("Masked X")
    ax3.axis('off')
    if y is not None:
        ax4 = fig.add_subplot(4,1,4)
        ax4.imshow(y.detach().numpy().T,aspect='auto')
        ax4.set_title("True")
        ax4.axis('off')

# %%
model.compute_acc(out,X,y)
# Out:
# 97.035

# %%
torch.argmax(torch.tensor([0,0,0]))
# Out:
# tensor(2)

# %%
i = next(n_iter)
print("Accuracy {} %".format(model.compute_acc(out[i].unsqueeze(dim=0),X[i].unsqueeze(dim=0),y[i].unsqueeze(dim=0))))
print("i=%d"%i)
visiualize_result(out[i],re_X[i],X[i],y[i])

fig=  plt.figure(figsize=(15,2.5))
ax = fig.gca()
ax.axis("off")
ax.imshow((re_X[i]-y[i]).detach().numpy().T,aspect='auto');
ax.set_title("Error site");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ed89e24827df> in <module>
# ----> 1 i = next(n_iter)
#       2 print("Accuracy {} %".format(model.compute_acc(out[i].unsqueeze(dim=0),X[i].unsqueeze(dim=0),y[i].unsqueeze(dim=0))))
#       3 print("i=%d"%i)
#       4 visiualize_result(out[i],re_X[i],X[i],y[i])
#       5
#
# NameError: name 'n_iter' is not defined

# %%
2*99/3
# Out:
# 66.0

# %% [markdown]
# # regression model

# %%
import PATH
from models import Baseline_models
from models import log_and_save as LAS
from models.popen import Auto_popen
from importlib import reload

from models import popen
reload(reader)
reload(popen)
# Out:
# <module 'models.popen' from '/home/wergillius/Project/UTR_VAE/models/popen.py'>

# %% [markdown]
# <font size=4 color='skyblue'>**Popen**</font>
#
#
# <font size=4 color='skyblue'>**Load DataLoader**</font>

# %%
def regression_result(config_path):
    

    """read config and popen"""
    unmod_mse_popen = popen.Auto_popen(config_path)


    """read model"""
    mse_model = unmod_mse_popen.Model_Class(*unmod_mse_popen.model_args)
    check_point = torch.load(unmod_mse_popen.vae_pth_path)
    mse_model.load_state_dict(check_point['state_dict'])
    mse_model=mse_model.cuda()


    """read data"""
    dataset = reader.MTL_enc_dataset(unmod_mse_popen.csv_path,pad_to=101,columns=['indexx','rl'])
    train_loader,val_loader = reader.get_splited_dataloader(dataset,
                                                ratio=[0.8,0.2],
                                                batch_size=168,
                                                num_workers=8)
    """list"""
    Y_true = []
    index_ls = []
    Y_pred = []
    utr = []
    
    """forward"""
    with torch.no_grad():
        for data in tqdm(val_loader):
            X,Y = data
            X = X.float().cuda()
            index_ls.append(Y[:,0].numpy())
            Y_true.append(Y[:,1].numpy())

            out = mse_model(X)
            Y_pred.append(out.cpu().numpy())
            
            torch.cuda.empty_cache()

    Y_pred = np.concatenate(Y_pred).squeeze()
    Y_true = np.concatenate(Y_true).squeeze()
    index_ls = np.concatenate(index_ls).squeeze()

    unmod_df = pd.read_csv('/data/users/wergillius/UTR_VAE/multi_task/scaled_unmod.csv')
    
    """get sequence by index"""
    val_df = unmod_df.loc[index_ls,['utr']]

    detect_atg = lambda x: 'ATG' in x

    val_df.loc[:,'Y_true'] = Y_true
    val_df.loc[:,'Y_pred'] = Y_pred
    val_df.loc[:,'uATG'] = val_df.utr.apply(detect_atg)
    
    return val_df

# %%
sns.set_style("white")
# sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'black'})
plt.rcParams['font.weight'] = 'normal'
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['axes.labelpad'] = 5
plt.rcParams['axes.linewidth']= 2
plt.rcParams['xtick.labelsize']= 14
plt.rcParams['ytick.labelsize']= 14
plt.rcParams['xtick.major.size'] = 6
plt.rcParams['ytick.major.size'] = 6
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.color'] = 'black' 
plt.rcParams['ytick.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['axes.edgecolor'] = 'black'

# fig = plt.figure(figsize=(9,9))
# ax = fig.gca()
# dots = ax.scatter(Y_true,Y_pred,s=20,alpha=0.2,color=(0.3, 0.45, 0.69))
# ax1 = 

def sns_kde_scatter(val_df):
    atg = val_df[val_df.uATG == True]
    n_atg = val_df[val_df.uATG == False]
    c1 = (0.3, 0.45, 0.69)
    c2 = 'darkred'
    g = sns.JointGrid(x='Y_true', y="Y_pred", data=atg, space=0, ratio=6, height=7)
    g.plot_joint(plt.scatter,s=15, color=c1, linewidth=0.2, alpha=0.1, edgecolor='black')
    f = g.fig
    ax = f.gca()
    # ax.set_yticks(np.arange(0,9.01, 1));
    # ax.set_yticklabels(range(10),size=20);
    # ax.set_xticks(np.arange(1,10.01, 1));
    # ax.set_xticklabels(range(1,11),size=20);
    ax.set_ylim(0.5,11)
    ax.set_xlim(0.5,11)
    g.plot_marginals(sns.kdeplot,shade=c1, **{'linewidth':2, 'color':c1})
    g.set_axis_labels('Observed MRL', 'Predicted MRL', **{'size':22});



    g.x = n_atg['Y_true'].values
    g.y = n_atg['Y_pred'].values
    g.plot_joint(plt.scatter, s=15, linewidth=0.2, alpha=0.2, color=c2, edgecolor='black')
    g.plot_marginals(sns.kdeplot, shade=c2, **{'linewidth':2, 'color':c2})
    f = g.fig

# %%
hinge = regression_result("/home/wergillius/Project/UTR_VAE/log/Baseline_MTL/unmod_df/unmod_hinge.ini")
# Out:
# 100%|██████████| 334/334 [00:43<00:00,  7.72it/s]

# %% [markdown]
# ## plot regression

# %%
RL_backbone = regression_result("/home/wergillius/Project/UTR_VAE/log/Backbone/RL_regressor_MTL/test_run/RL_test.ini")
# Out:
# 100%|██████████| 334/334 [00:35<00:00,  9.42it/s]

# %%
sns_kde_scatter(RL_backbone)

# %%
sns_kde_scatter(val_df)

# %%
sns_kde_scatter(hinge)
